# %%
# Data Exctraction.....

import pandas as pd
import requests
from bs4 import BeautifulSoup

# Read input Excel file
input_file = "Input.xlsx"
df_input = pd.read_excel(input_file)

# Function to extract article text from URL
def extract_article_text(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Find article title and text
        title = soup.find("tittle").text.strip()
        article_text = ""
        for paragraph in soup.find_all("p"):
            article_text += paragraph.text.strip() + "\n"

        return title, article_text
    except Exception as e:
        print(f"Error extracting article from {url}: {e}")
        return None, None

# Iterate over each row in the DataFrame
for index, row in df_input.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    
    # Extract article text
    title, article_text = extract_article_text(url)
    
    if title and article_text:
        # Save extracted text to a text file
        with open(f"{url_id}.txt", "w", encoding="utf-8") as file:
            file.write(f"Title: {title}\n\n")
            file.write(article_text)
        print(f"Article extracted and saved for URL_ID: {url_id}")
    else:
        print(f"Skipping URL_ID: {url_id}")

print("Extraction complete.")
# Out:
# Error extracting article from https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0001
# Error extracting article from https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0002
# Error extracting article from https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0003
# Error extracting article from https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0004
# Error extracting article from https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0005
# Error extracting article from https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0006
# Error extracting article from https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0007
# Error extracting article from https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0008
# Error extracting article from https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0009
# Error extracting article from https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0010
# Error extracting article from https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0011
# Error extracting article from https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0012
# Error extracting article from https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0013
# Error extracting article from https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0014
# Error extracting article from https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0015
# Error extracting article from https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0016
# Error extracting article from https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0017
# Error extracting article from https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0018
# Error extracting article from https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0019
# Error extracting article from https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0020
# Error extracting article from https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0021
# Error extracting article from https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0022
# Error extracting article from https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0023
# Error extracting article from https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0024
# Error extracting article from https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0025
# Error extracting article from https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0026
# Error extracting article from https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0027
# Error extracting article from https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0028
# Error extracting article from https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0029
# Error extracting article from https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0030
# Error extracting article from https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0031
# Error extracting article from https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0032
# Error extracting article from https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0033
# Error extracting article from https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0034
# Error extracting article from https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0035
# Error extracting article from https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0036
# Error extracting article from https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0037
# Error extracting article from https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0038
# Error extracting article from https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0039
# Error extracting article from https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0040
# Error extracting article from https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0041
# Error extracting article from https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0042
# Error extracting article from https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0043
# Error extracting article from https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0044
# Error extracting article from https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0045
# Error extracting article from https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0046
# Error extracting article from https://insights.blackcoffer.com/evolution-of-advertising-industry/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0047
# Error extracting article from https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0048
# Error extracting article from https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0049
# Error extracting article from https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0050
# Error extracting article from https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0051
# Error extracting article from https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0052
# Error extracting article from https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0053
# Error extracting article from https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0054
# Error extracting article from https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0055
# Error extracting article from https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0056
# Error extracting article from https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0057
# Error extracting article from https://insights.blackcoffer.com/how-we-forecast-future-technologies/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0058
# Error extracting article from https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0059
# Error extracting article from https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0060
# Error extracting article from https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0061
# Error extracting article from https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0062
# Error extracting article from https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0063
# Error extracting article from https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0064
# Error extracting article from https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0065
# Error extracting article from https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0066
# Error extracting article from https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0067
# Error extracting article from https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0068
# Error extracting article from https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0069
# Error extracting article from https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0070
# Error extracting article from https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0071
# Error extracting article from https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0072
# Error extracting article from https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0073
# Error extracting article from https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0074
# Error extracting article from https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0075
# Error extracting article from https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0076
# Error extracting article from https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0077
# Error extracting article from https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0078
# Error extracting article from https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0079
# Error extracting article from https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0080
# Error extracting article from https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0081
# Error extracting article from https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0082
# Error extracting article from https://insights.blackcoffer.com/human-rights-outlook/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0083
# Error extracting article from https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0084
# Error extracting article from https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0085
# Error extracting article from https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0086
# Error extracting article from https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0087
# Error extracting article from https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0088
# Error extracting article from https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0089
# Error extracting article from https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0090
# Error extracting article from https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0091
# Error extracting article from https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0092
# Error extracting article from https://insights.blackcoffer.com/travel-and-tourism-outlook/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0093
# Error extracting article from https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0094
# Error extracting article from https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0095
# Error extracting article from https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0096
# Error extracting article from https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0097
# Error extracting article from https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0098
# Error extracting article from https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0099
# Error extracting article from https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/: 'NoneType' object has no attribute 'text'
# Skipping URL_ID: blackassign0100
# Extraction complete.

# %%
# Data Analysis....
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
import nltk
nltk.download('vader_lexicon')

# Read output structure Excel file
output_file = "Output Data Structure.xlsx"
df_output = pd.read_excel(output_file)

# Function to compute variables from article text
def compute_variables(article_text):
    # Tokenize the article text
    tokens = word_tokenize(article_text.lower())
    
    # Remove stopwords
    stop_words = set(stopwords.words("english"))
    filtered_words = [word for word in tokens if word not in stop_words and word.isalpha()]
    
    # Compute word frequency
    freq_dist = FreqDist(filtered_words)
    top_words = freq_dist.most_common(10)
    
    # Compute sentiment
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(article_text)
    sentiment_label = "Positive" if sentiment_score["compound"] > 0 else "Negative" if sentiment_score["compound"] < 0 else "Neutral"
    
    # Return computed variables
    return len(filtered_words), sentiment_label

# Iterate over each row in the DataFrame
for index, row in df_output.iterrows():
    url_id = row['URL_ID']
    
    # Read article text from saved text file
    try:
        with open(f"{url_id}.txt", "r", encoding="utf-8") as file:
            article_text = file.read()
        
        # Compute variables
        word_count, sentiment = compute_variables(article_text)
        
        # Update DataFrame with computed variables
        df_output.at[index, 'Word_Count'] = word_count
        df_output.at[index, 'Sentiment'] = sentiment
        
        print(f"Variables computed for URL_ID: {url_id}")
    except FileNotFoundError:
        print(f"Text file not found for URL_ID: {url_id}")

# Save computed variables to a new Excel file
output_variables_file = "input.xlsx"
df_output.to_excel(output_variables_file, index=False)

print("DONE...")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# C:\Users\abhis\AppData\Local\Temp\ipykernel_12416\1114211601.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Positive' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_output.at[index, 'Sentiment'] = sentiment
# Variables computed for URL_ID: blackassign0001
# Variables computed for URL_ID: blackassign0002
# Variables computed for URL_ID: blackassign0003
# Variables computed for URL_ID: blackassign0004
# Variables computed for URL_ID: blackassign0005
# Variables computed for URL_ID: blackassign0006
# Variables computed for URL_ID: blackassign0007
# Variables computed for URL_ID: blackassign0008
# Variables computed for URL_ID: blackassign0009
# Variables computed for URL_ID: blackassign0010
# Variables computed for URL_ID: blackassign0011
# Variables computed for URL_ID: blackassign0012
# Variables computed for URL_ID: blackassign0013
# Variables computed for URL_ID: blackassign0014
# Variables computed for URL_ID: blackassign0015
# Variables computed for URL_ID: blackassign0016
# Variables computed for URL_ID: blackassign0017
# Variables computed for URL_ID: blackassign0018
# Variables computed for URL_ID: blackassign0019
# Variables computed for URL_ID: blackassign0020
# Variables computed for URL_ID: blackassign0021
# Variables computed for URL_ID: blackassign0022
# Variables computed for URL_ID: blackassign0023
# Variables computed for URL_ID: blackassign0024
# Variables computed for URL_ID: blackassign0025
# Variables computed for URL_ID: blackassign0026
# Variables computed for URL_ID: blackassign0027
# Variables computed for URL_ID: blackassign0028
# Variables computed for URL_ID: blackassign0029
# Variables computed for URL_ID: blackassign0030
# Variables computed for URL_ID: blackassign0031
# Variables computed for URL_ID: blackassign0032
# Variables computed for URL_ID: blackassign0033
# Variables computed for URL_ID: blackassign0034
# Variables computed for URL_ID: blackassign0035
# Variables computed for URL_ID: blackassign0036
# Variables computed for URL_ID: blackassign0037
# Variables computed for URL_ID: blackassign0038
# Variables computed for URL_ID: blackassign0039
# Variables computed for URL_ID: blackassign0040
# Variables computed for URL_ID: blackassign0041
# Variables computed for URL_ID: blackassign0042
# Variables computed for URL_ID: blackassign0043
# Variables computed for URL_ID: blackassign0044
# Variables computed for URL_ID: blackassign0045
# Variables computed for URL_ID: blackassign0046
# Variables computed for URL_ID: blackassign0047
# Variables computed for URL_ID: blackassign0048
# Variables computed for URL_ID: blackassign0049
# Variables computed for URL_ID: blackassign0050
# Variables computed for URL_ID: blackassign0051
# Variables computed for URL_ID: blackassign0052
# Variables computed for URL_ID: blackassign0053
# Variables computed for URL_ID: blackassign0054
# Variables computed for URL_ID: blackassign0055
# Variables computed for URL_ID: blackassign0056
# Variables computed for URL_ID: blackassign0057
# Variables computed for URL_ID: blackassign0058
# Variables computed for URL_ID: blackassign0059
# Variables computed for URL_ID: blackassign0060
# Variables computed for URL_ID: blackassign0061
# Variables computed for URL_ID: blackassign0062
# Variables computed for URL_ID: blackassign0063
# Variables computed for URL_ID: blackassign0064
# Variables computed for URL_ID: blackassign0065
# Variables computed for URL_ID: blackassign0066
# Variables computed for URL_ID: blackassign0067
# Variables computed for URL_ID: blackassign0068
# Variables computed for URL_ID: blackassign0069
# Variables computed for URL_ID: blackassign0070
# Variables computed for URL_ID: blackassign0071
# Variables computed for URL_ID: blackassign0072
# Variables computed for URL_ID: blackassign0073
# Variables computed for URL_ID: blackassign0074
# Variables computed for URL_ID: blackassign0075
# Variables computed for URL_ID: blackassign0076
# Variables computed for URL_ID: blackassign0077
# Variables computed for URL_ID: blackassign0078
# Variables computed for URL_ID: blackassign0079
# Variables computed for URL_ID: blackassign0080
# Variables computed for URL_ID: blackassign0081
# Variables computed for URL_ID: blackassign0082
# Variables computed for URL_ID: blackassign0083
# Variables computed for URL_ID: blackassign0084
# Variables computed for URL_ID: blackassign0085
# Variables computed for URL_ID: blackassign0086
# Variables computed for URL_ID: blackassign0087
# Variables computed for URL_ID: blackassign0088
# Variables computed for URL_ID: blackassign0089
# Variables computed for URL_ID: blackassign0090
# Variables computed for URL_ID: blackassign0091
# Variables computed for URL_ID: blackassign0092
# Variables computed for URL_ID: blackassign0093
# Variables computed for URL_ID: blackassign0094
# Variables computed for URL_ID: blackassign0095
# Variables computed for URL_ID: blackassign0096
# Variables computed for URL_ID: blackassign0097
# Variables computed for URL_ID: blackassign0098
# Variables computed for URL_ID: blackassign0099
# Variables computed for URL_ID: blackassign0100
# DONE...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.sentiment import SentimentIntensityAnalyzer
from textstat import flesch_reading_ease, gunning_fog, syllable_count

# Read output structure Excel file
output_file = "Output Data Structure.xlsx"
df_output = pd.read_excel(output_file)

# Function to compute variables from article text
def compute_variables(article_text):
    # Tokenize the article text
    tokens = word_tokenize(article_text.lower())
    
    # Remove stopwords
    stop_words = set(stopwords.words("english"))
    filtered_words = [word for word in tokens if word not in stop_words and word.isalpha()]
    
    # Compute word count
    word_count = len(filtered_words)
    
    # Compute average word length
    avg_word_length = sum(len(word) for word in filtered_words) / word_count
    
    # Compute sentiment
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(article_text)
    sentiment_label = "Positive" if sentiment_score["compound"] > 0 else "Negative" if sentiment_score["compound"] < 0 else "Neutral"
    
    # Compute POSITIVE SCORE, NEGATIVE SCORE, POLARITY SCORE, SUBJECTIVITY SCORE
    positive_score = sentiment_score["pos"]
    negative_score = sentiment_score["neg"]
    polarity_score = sentiment_score["compound"]
    subjectivity_score = sentiment_score["compound"] + sentiment_score["neu"]
    
    # Compute average sentence length
    sentences = sent_tokenize(article_text)
    avg_sentence_length = sum(len(word_tokenize(sent)) for sent in sentences) / len(sentences)
    
    # Compute percentage of complex words
    complex_words = [word for word in filtered_words if syllable_count(word) >= 3]
    percentage_complex_words = (len(complex_words) / len(filtered_words)) * 100
    
    # Compute FOG INDEX
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    
    # Compute average number of words per sentence
    avg_words_per_sentence = len(filtered_words) / len(sentences)
    
    # Compute complex word count
    complex_word_count = len(complex_words)
    
    # Compute syllables per word
    syllables_per_word = sum(syllable_count(word) for word in filtered_words) / len(filtered_words)
    
    # Count personal pronouns
    personal_pronouns = ["I", "me", "my", "mine", "myself", "we", "us", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves"]
    personal_pronoun_count = sum(1 for word in filtered_words if word in personal_pronouns)
    
    # Return computed variables as a dictionary
    return {
        'Word_Count': word_count,
        'Avg_Word_Length': avg_word_length,
        'Positive_Score': positive_score,
        'Negative_Score': negative_score,
        'Polarity_Score': polarity_score,
        'Subjectivity_Score': subjectivity_score,
        'Avg_Sentence_Length': avg_sentence_length,
        'Percentage_of_Complex_Words': percentage_complex_words,
        'FOG_Index': fog_index,
        'Avg_Number_of_Words_Per_Sentence': avg_words_per_sentence,
        'Complex_Word_Count': complex_word_count,
        'Syllable_Per_Word': syllables_per_word,
        'Personal_Pronouns': personal_pronoun_count
    }

# Iterate over each row in the DataFrame
for index, row in df_output.iterrows():
    url_id = row['URL_ID']
    
    # Read article text from saved text file
    try:
        with open(f"{url_id}.txt", "r", encoding="utf-8") as file:
            article_text = file.read()
        
        # Compute variables
        variables = compute_variables(article_text)
        
        # Update DataFrame with computed variables
        for key, value in variables.items():
            df_output.at[index, key] = value
        
        print(f"Variables computed for URL_ID: {url_id}")
    except FileNotFoundError:
        print(f"Text file not found for URL_ID: {url_id}")

# Save computed variables to a new Excel file
output_variables_file = "input.xlsx"
df_output.to_excel(output_variables_file, index=False)

print("Data analysis complete.")
# Out:
# Variables computed for URL_ID: blackassign0001
# Variables computed for URL_ID: blackassign0002
# Variables computed for URL_ID: blackassign0003
# Variables computed for URL_ID: blackassign0004
# Variables computed for URL_ID: blackassign0005
# Variables computed for URL_ID: blackassign0006
# Variables computed for URL_ID: blackassign0007
# Variables computed for URL_ID: blackassign0008
# Variables computed for URL_ID: blackassign0009
# Variables computed for URL_ID: blackassign0010
# Variables computed for URL_ID: blackassign0011
# Variables computed for URL_ID: blackassign0012
# Variables computed for URL_ID: blackassign0013
# Variables computed for URL_ID: blackassign0014
# Variables computed for URL_ID: blackassign0015
# Variables computed for URL_ID: blackassign0016
# Variables computed for URL_ID: blackassign0017
# Variables computed for URL_ID: blackassign0018
# Variables computed for URL_ID: blackassign0019
# Variables computed for URL_ID: blackassign0020
# Variables computed for URL_ID: blackassign0021
# Variables computed for URL_ID: blackassign0022
# Variables computed for URL_ID: blackassign0023
# Variables computed for URL_ID: blackassign0024
# Variables computed for URL_ID: blackassign0025
# Variables computed for URL_ID: blackassign0026
# Variables computed for URL_ID: blackassign0027
# Variables computed for URL_ID: blackassign0028
# Variables computed for URL_ID: blackassign0029
# Variables computed for URL_ID: blackassign0030
# Variables computed for URL_ID: blackassign0031
# Variables computed for URL_ID: blackassign0032
# Variables computed for URL_ID: blackassign0033
# Variables computed for URL_ID: blackassign0034
# Variables computed for URL_ID: blackassign0035
# Variables computed for URL_ID: blackassign0036
# Variables computed for URL_ID: blackassign0037
# Variables computed for URL_ID: blackassign0038
# Variables computed for URL_ID: blackassign0039
# Variables computed for URL_ID: blackassign0040
# Variables computed for URL_ID: blackassign0041
# Variables computed for URL_ID: blackassign0042
# Variables computed for URL_ID: blackassign0043
# Variables computed for URL_ID: blackassign0044
# Variables computed for URL_ID: blackassign0045
# Variables computed for URL_ID: blackassign0046
# Variables computed for URL_ID: blackassign0047
# Variables computed for URL_ID: blackassign0048
# Variables computed for URL_ID: blackassign0049
# Variables computed for URL_ID: blackassign0050
# Variables computed for URL_ID: blackassign0051
# Variables computed for URL_ID: blackassign0052
# Variables computed for URL_ID: blackassign0053
# Variables computed for URL_ID: blackassign0054
# Variables computed for URL_ID: blackassign0055
# Variables computed for URL_ID: blackassign0056
# Variables computed for URL_ID: blackassign0057
# Variables computed for URL_ID: blackassign0058
# Variables computed for URL_ID: blackassign0059
# Variables computed for URL_ID: blackassign0060
# Variables computed for URL_ID: blackassign0061
# Variables computed for URL_ID: blackassign0062
# Variables computed for URL_ID: blackassign0063
# Variables computed for URL_ID: blackassign0064
# Variables computed for URL_ID: blackassign0065
# Variables computed for URL_ID: blackassign0066
# Variables computed for URL_ID: blackassign0067
# Variables computed for URL_ID: blackassign0068
# Variables computed for URL_ID: blackassign0069
# Variables computed for URL_ID: blackassign0070
# Variables computed for URL_ID: blackassign0071
# Variables computed for URL_ID: blackassign0072
# Variables computed for URL_ID: blackassign0073
# Variables computed for URL_ID: blackassign0074
# Variables computed for URL_ID: blackassign0075
# Variables computed for URL_ID: blackassign0076
# Variables computed for URL_ID: blackassign0077
# Variables computed for URL_ID: blackassign0078
# Variables computed for URL_ID: blackassign0079
# Variables computed for URL_ID: blackassign0080
# Variables computed for URL_ID: blackassign0081
# Variables computed for URL_ID: blackassign0082
# Variables computed for URL_ID: blackassign0083
# Variables computed for URL_ID: blackassign0084
# Variables computed for URL_ID: blackassign0085
# Variables computed for URL_ID: blackassign0086
# Variables computed for URL_ID: blackassign0087
# Variables computed for URL_ID: blackassign0088
# Variables computed for URL_ID: blackassign0089
# Variables computed for URL_ID: blackassign0090
# Variables computed for URL_ID: blackassign0091
# Variables computed for URL_ID: blackassign0092
# Variables computed for URL_ID: blackassign0093
# Variables computed for URL_ID: blackassign0094
# Variables computed for URL_ID: blackassign0095
# Variables computed for URL_ID: blackassign0096
# Variables computed for URL_ID: blackassign0097
# Variables computed for URL_ID: blackassign0098
# Variables computed for URL_ID: blackassign0099
# Variables computed for URL_ID: blackassign0100
# Data analysis complete.

# %%
# complete assignment
